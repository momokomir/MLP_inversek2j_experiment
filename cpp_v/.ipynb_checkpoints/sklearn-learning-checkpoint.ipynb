# %%
from sklearn.neural_network import MLPRegressor
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from fann2 import libfann

# %%
# fann
num_layers = 3
num_input = 1
num_hidden = 8
num_output = 1

ann = libfann.neural_net(num_layers, num_input, num_hidden, num_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-88c71df21449> in <module>()
#       5 num_output = 1
#       6
# ----> 7 ann = libfann.neural_net(num_layers, num_input, num_hidden, num_output)
#       8
#
# NameError: name 'num_hidden' is not defined

# %%
X = np.linspace(0,2*np.pi,100)
y = np.sin(X).ravel()
X = X.reshape(-1,1)
# MLPRegressor
regr_3 = MLPRegressor(hidden_layer_sizes=(200,),max_iter=10000,activation='tanh')
regr_3.fit(X, y)
y_3 = regr_3.predict(X)
print("R-squre: %s"%regr_3.score(X, y))
plt.figure()
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_3, c="r", label="MLORegressor", linewidth=2)
plt.legend()
plt.show()
# Out:
# R-squre: 0.603484991801

# %%
X = np.linspace(0,2*np.pi,100)
y = np.sin(X).ravel()
X = X.reshape(-1,1)
# MLPRegressor
regr_3 = MLPRegressor(hidden_layer_sizes=(200,200),max_iter=10000,activation='logistic')
regr_3.fit(X, y)
y_3 = regr_3.predict(X)
print("R-squre: %s"%regr_3.score(X, y))
plt.figure()
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_3, c="r", label="MLORegressor", linewidth=2)
plt.legend()
plt.show()
# Out:
# R-squre: -0.041308119551

# %%
X = np.linspace(0,2*np.pi,100)
y = np.sin(X).ravel()
X = X.reshape(-1,1)
# MLPRegressor
regr_3 = MLPRegressor(hidden_layer_sizes=(200,),max_iter=10000)
regr_3.fit(X, y)
y_3 = regr_3.predict(X)
print("R-squre: %s"%regr_3.score(X, y))
plt.figure()
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_3, c="r", label="MLORegressor", linewidth=2)
plt.legend()
plt.show()
# Out:
# R-squre: 0.931577052577

# %%
# Create the dataset
rng = np.random.RandomState(1)
X = np.linspace(0, 6, 100)[:, np.newaxis]
y = np.sin(X).ravel() + np.sin(6 * X).ravel() + rng.normal(0, 0.1, X.shape[0])
# MLPRegressor
regr_3 = MLPRegressor(hidden_layer_sizes=(2,),max_iter=10000)
regr_3.fit(X, y)
y_3 = regr_3.predict(X)
print("R-squre: %s"%regr_3.score(X, y))
regr_4 = MLPRegressor(hidden_layer_sizes=(4,),max_iter=10000)
regr_4.fit(X, y)
y_4 = regr_4.predict(X)
print("R-squre: %s"%regr_4.score(X, y))

regr_4 = MLPRegressor(hidden_layer_sizes=(8,),max_iter=10000)
regr_4.fit(X, y)
y_4 = regr_4.predict(X)
print("R-squre: %s"%regr_4.score(X, y))

regr_4 = MLPRegressor(hidden_layer_sizes=(16,),max_iter=10000)
regr_4.fit(X, y)
y_4 = regr_4.predict(X)
print("R-squre: %s"%regr_4.score(X, y))

# %%
# Create the dataset
rng = np.random.RandomState(1)
X = np.linspace(0, 6, 100)[:, np.newaxis]
y = np.sin(X).ravel() + np.sin(6 * X).ravel() + rng.normal(0, 0.1, X.shape[0])
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=4),
                          n_estimators=300, random_state=rng)

regr_1.fit(X, y)
regr_2.fit(X, y)


# Predict
y_1 = regr_1.predict(X)
y_2 = regr_2.predict(X)
# Plot the results
plt.figure()
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_1, c="g", label="n_estimators=1", linewidth=2)
plt.plot(X, y_2, c="r", label="n_estimators=300", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Boosted Decision Tree Regression")
plt.legend()
plt.show()
